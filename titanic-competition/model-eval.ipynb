# %%
import pandas as pd
import seaborn as sns
sns.set(style='darkgrid')

# %%
loss_curve = pd.read_csv("catboost_info/learn_error.tsv", sep="\t", index_col="iter")
sns.lineplot(x='iter', y='CrossEntropy', data=loss_curve);
